# %% [markdown]
# # Inclass Exercies for lecture 20

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercise One

# %%
from scipy.integrate import quad, tplquad

# %%
def my_function(x):
    return np.sin(x)**2

# %%
val, err = quad(my_function, 0, 10)

# %%
print(val)
# Out:
# 4.771763687318093

# %%
5-np.sin(20)/4
# Out:
# 4.771763687318093

# %% [markdown]
# ## Exercise Two

# %%
val, err = tplquad(lambda z, y, x: x*y*z, 0, 1, 2, 3, 0, 1)

# %%
val
# Out:
# 0.625

# %%
5/8
# Out:
# 0.625

# %% [markdown]
# ## Exercise Three

# %%
from scipy.integrate import odeint

# %%
def dS(S, t):
    x, y = S[:]
    return ([(2/3)*x - (4/3)*x*y, 
            x*y - y])

# %%
S_0 = [1, 1]

# %%
t = np.linspace(0, 20, 200)

# %%
S = odeint(dS, S_0, t)

# %%
plt.plot(t, S[:, 0])
plt.plot(t, S[:, 1])

# %%
plt.plot(S[:, 0], S[:, 1])

# %% [markdown]
# ## Exercise Four

# %%
from scipy.optimize import root

# %%
answer = root(lambda x: 5 * x ** 2 + 9 * x - 80, 3.5)

# %%
print(f'A root was found at x = {answer.x[0]:.2f}')
# Out:
# A root was found at x = 3.20

# %% [markdown]
# ## Exercise Five

# %%
from scipy.optimize import curve_fit

# %%
x_data = np.array([0.        , 0.20833333, 0.41666667, 0.625     , 0.83333333,
       1.04166667, 1.25      , 1.45833333, 1.66666667, 1.875     ,
       2.08333333, 2.29166667, 2.5       , 2.70833333, 2.91666667,
       3.125     , 3.33333333, 3.54166667, 3.75      , 3.95833333,
       4.16666667, 4.375     , 4.58333333, 4.79166667, 5.        ])
y_data = np.array([ 1.17640523,  0.7707544 ,  0.35389549,  0.00494593, -0.34139062,
       -0.69167134, -0.34420493, -0.17479235,  0.11295719,  0.35086045,
        0.36707616,  0.40931083,  0.17541645, -0.05694585, -0.13725686,
       -0.17598432, -0.00907223, -0.08215067,  0.06990463,  0.02104389,
       -0.13105866,  0.16050284,  0.12461478, -0.09567864,  0.16461648])

# %%
def func(x, a, b):
    return np.exp(-a*x)*np.cos(b*x)

# %%
params, cov = curve_fit(func, x_data, y_data)

# %%
params
# Out:
# array([0.54999688, 2.89627577])

# %%
x = np.linspace(x_data.min(), x_data.max(), 200)

# %%
plt.plot(x_data, y_data, 'o')
plt.plot(x, func(x, *params))
